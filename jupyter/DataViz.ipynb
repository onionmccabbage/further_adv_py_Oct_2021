# %% [markdown]
# ## Visualizing Data with Charts

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas import DataFrame, Series

# %%
# set some chart defaults
plt.rc('figure', figsize=(10,6))

# %%
data = np.arange(10)
data
plt.plot(data)

# %%
# sometimes we want several charts in one figure
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,3)
# ax4 = fig.add_subplot(2,2,4)

# %%
# format the appearance of the chart
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))
_ # a simple variable name!!!
# Out:
# (array([ 2.,  1.,  0.,  4.,  5.,  5.,  4.,  3.,  9.,  9.,  9.,  3.,  7.,
#         15., 11.,  3.,  6.,  0.,  3.,  1.]),
#  array([-2.70360465, -2.46934577, -2.23508689, -2.00082801, -1.76656913,
#         -1.53231025, -1.29805137, -1.06379249, -0.82953361, -0.59527473,
#         -0.36101586, -0.12675698,  0.1075019 ,  0.34176078,  0.57601966,
#          0.81027854,  1.04453742,  1.2787963 ,  1.51305518,  1.74731406,
#          1.98157293]),
#  <BarContainer object of 20 artists>)

# %%
ig, axes = plt.subplots(2,2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i,j].hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
plt.subplots_adjust(wspace=0, hspace=0)
